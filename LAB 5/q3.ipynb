# %%
from collections import deque

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BinaryTree:
    def __init__(self):
        self.root = None

    def add_node(self, value):
        new_node = TreeNode(value)
        if self.root is None:
            self.root = new_node
            return
        q = deque([self.root])
        while q:
            node = q.popleft()
            if node.left is None:
                node.left = new_node
                return
            else:
                q.append(node.left)
            if node.right is None:
                node.right = new_node
                return
            else:
                q.append(node.right)

    def count_nodes(self, node):
        if node is None:
            return 0
        return 1 + self.count_nodes(node.left) + self.count_nodes(node.right)

    def height(self, node):
        if node is None:
            return 0
        return 1 + max(self.height(node.left), self.height(node.right))

    def remove_node(self, value):
        if self.root is None:
            return
        if self.root.value == value:
            self.root = None
            return
        q = deque([self.root])
        while q:
            node = q.popleft()
            if node.left:
                if node.left.value == value:
                    node.left = None
                    return
                q.append(node.left)
            if node.right:
                if node.right.value == value:
                    node.right = None
                    return
                q.append(node.right)

bt = BinaryTree()
bt.add_node(10)
bt.add_node(20)
bt.add_node(30)
bt.add_node(40)
print("Total Nodes:", bt.count_nodes(bt.root))
print("Height of Tree:", bt.height(bt.root))
bt.remove_node(20)
                    node.left = None
                    return
                q.append(node.left)

            if node.right:
                if node.right.value == value:
                    node.right = None
                    return
                q.append(node.right)
bt = BinaryTree()

bt.add_node(10)
bt.add_node(20)
bt.add_node(30)
bt.add_node(40)

print("Total Nodes:", bt.count_nodes(bt.root))
print("Height of Tree:", bt.height(bt.root))

bt.remove_node(20)
print("Total Nodes after deletion:", bt.count_nodes(bt.root))
# Out:
# Total Nodes: 4
# Height of Tree: 3
# Total Nodes after deletion: 2
