# %%
class Box:
    def __init__(self, length, width, height):
        self.length = length
        self.width = width
        self.height = height
    
    def volume(self):
        return self.length * self.width * self.height

box1 = Box(5, 4, 3)
print(f"Length: {box1.length}")
print(f"Width: {box1.width}")
print(f"Height: {box1.height}")
print(f"Volume: {box1.volume()} cubic units")
