# %% [markdown]
# # Q.2) Check if set is subset of another

# %%
set1 = {1, 2, 3}
set2 = {1, 2, 3, 4, 5}

print(f"Set1: {set1}")
print(f"Set2: {set2}")
print(f"Is set1 subset of set2: {set1.issubset(set2)}")
print(f"Is set2 subset of set1: {set2.issubset(set1)}")
