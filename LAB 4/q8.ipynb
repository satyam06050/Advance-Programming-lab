# %% [markdown]
# # Q.8) Factorial using user-defined function

# %%
def fact(n):
    if n <= 1:
        return 1
    return n * fact(n-1)

num = int(input("Enter number: "))
print("Factorial:", fact(num))
