# %% [markdown]
# # Q.5) Dictionary operations - create, fetch, add, concatenate

# %%
d1 = {"name": "John", "age": 20}
k = input("Enter key: ")
print(d1.get(k, "Not found"))

d2 = {}
d2["city"] = "Delhi"
d2["job"] = "Student"

d3 = d1.copy()
d3.update(d2)
print(d3)
