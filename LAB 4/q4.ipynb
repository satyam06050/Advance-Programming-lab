# %% [markdown]
# # Q.4) Create immutable set, print using iterator, add element

# %%
s = frozenset([1, 2, 3, 4, 5])
print("Original set:")
for i in s:
    print(i)

s2 = frozenset(list(s) + [6])
print("After adding 6:")
for i in s2:
    print(i)
