# %%
item = "b"

match item:
    case "a":
        print("matched a")
    case "b":
        print("matched b")
    case "c":
        print("matched c")
    case _:
        print("no match")
# Out:
# matched b

# %%
for i in range(0,10,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
while i<10:
    print(i*2)
