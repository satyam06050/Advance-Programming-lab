# %%
lst = [1, 2, 3, 4, 5, 6, 7, 8, 9, 4, 5, 7, 4, 3, 6, 7]
n = int(input("Enter number to search: "))

if n in lst:
    print(f"Element found at index: {lst.index(n)}")
else:
    print("Element not found!")
# Out:
# Element found in the list! Index= <method-wrapper '__index__' of int object at 0x000002622BB60170>
