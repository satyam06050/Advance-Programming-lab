# %% [markdown]
# # Q.6) Copy elements of list A to B, make them same

# %%
A = [1, 2, 3, 4, 5]
B = [10, 20, 30, 40, 50, 60, 70]

print(f"A: {A}")
print(f"B: {B}")

B.clear()
B.extend(A)

print(f"After copying A to B:")
print(f"A: {A}")
print(f"B: {B}")
